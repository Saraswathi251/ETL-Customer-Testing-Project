# %% [markdown]
# <a href="https://colab.research.google.com/github/Saraswathi251/ETL-Customer-Testing-Project/blob/main/python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

results = [
['TC001','Record Count Validation','PASS'],
['TC002','Null Validation','PASS'],
['TC003','Duplicate Validation','PASS'],
['TC004','Email Validation','PASS'],
['TC005','Country Validation','PASS'],
['TC006','Date Validation','PASS'],
['TC007','Data Comparison','PASS'],
['TC008','Aggregate Validation','PASS']
]

df = pd.DataFrame(results,
columns=['Test Case','Validation','Status'])

df.to_excel('ETL_Test_Report.xlsx',index=False)

print('Excel Report Generated Successfully')
# Out:
# Excel Report Generated Successfully
